# %% [markdown]
# # Exploración de datos

# %%
import pandas as pd

# %%
df_customer = pd.read_csv("../Data/eci_customer_data.csv")
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801923 entries, 0 to 801922
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   client_id        801923 non-null  int64
#  1   phone_number     705749 non-null  object
#  2   email_address    657079 non-null  object
#  3   city             801923 non-null  object
#  4   state            801923 non-null  object
#  5   zip_code         734663 non-null  object
#  6   education_level  682042 non-null  object
#  7   occupation       657407 non-null  object
#  8   loyalty_member   762074 non-null  object
#  9   loyalty_number   440681 non-null  object
#  10  loyalty_points   392749 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 67.3+ MB

# %%
df_customer.sample(25)
# Out:
#         client_id    phone_number                   email_address  \
# 335842     927723  (770) 508-6389           lisamorales@gmail.com
# 6273       508075  (919) 493-0512          andrewrogers@yahoo.com
# 83037      605716  (503) 246-8266         samplecool623@gmail.com
# 486322    1120083  (213) 407-1339   member24062+store@hotmail.com
# 47402      560122  (918) 811-1525                             NaN
# 130530     666304  (508) 461-3629                             NaN
# 66166      583989  (508) 452-0208              MEMBER2000@AOL.COM
# 278236     854786  (614) 305-7344  sample50798+shopping@gmail.com
# 482846    1115730  (412) 488-3062         memberbest794@gmail.com
# 274094     849461  (770) 392-6214                             NaN
# 424864    1041286             NaN                             NaN
# 351097     947194  (718) 708-0502     elizabeth.ortiz@hotmail.com
# 48795      561858             NaN                             NaN
# ...

# %%
df_product_groups = pd.read_csv('../Data/eci_product_groups.csv')
df_product_groups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sku               80 non-null     object
#  1   product_name      80 non-null     object
#  2   price_group_id    80 non-null     object
#  3   price_group_name  80 non-null     object
#  4   group_type        80 non-null     object
# dtypes: object(5)
# memory usage: 3.3+ KB

# %%
df_product_groups.sample(25)
# Out:
#            sku                    product_name      price_group_id  \
# 42  BOOFIMY002           ReadNow Guide Mystery    GIFT_UNDER_50_01
# 66  GROSNCH023  MarketEssentials Premium Chips      MOVIE_NIGHT_01
# 37  SPOFIAP005     FitZone Performance Apparel    FITNESS_COMBO_01
# 32  ELEMOAC001     Electra Accessories Ultra X       COMP_SETUP_01
# 23  ELEAUHE012      Innovate Headphones Mini X       COMP_SETUP_01
# 64  GROSNCH014        TastyBites Organic Chips      MOVIE_NIGHT_01
# 29  ELECOLA002       Electra Laptops Ultra Pro       COMP_SETUP_01
# 35  ELEMOAC009       TechPro Accessories Air X       COMP_SETUP_01
# 55  ELECOTA007        Innovate Tablets Mini XL   MOBILE_DEVICES_01
# 17  CLOWOBO007   ThreadWell Bottoms Collection   CASUAL_BOTTOMS_01
# 41  SPOFISU006      SportsGear Pro Supplements    FITNESS_COMBO_01
# 1   BOOEDTE002     Bookworm Advanced Textbooks   BACK_TO_SCHOOL_01
# 34  ELEMOAC008   ByteWare Accessories Air 2025       COMP_SETUP_01
# ...

# %%
df_product_master = pd.read_csv('../Data/eci_product_master.csv')
df_product_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sku                   861 non-null    object
#  1   product_name          861 non-null    object
#  2   category              861 non-null    object
#  3   group                 861 non-null    object
#  4   subgroup              861 non-null    object
#  5   brand                 861 non-null    object
#  6   base_price            861 non-null    float64
#  7   initial_ticket_price  861 non-null    float64
#  8   costos                861 non-null    float64
# dtypes: float64(3), object(6)
# memory usage: 60.7+ KB

# %%
df_product_master.sample(25)
# Out:
#             sku                           product_name        category  \
# 363  SPOFIAP006           SportsGear Endurance Apparel          Sports
# 383  SPOTESO003                  ActiveLife Pro Soccer          Sports
# 769  GROPABA006            PantryBasics Organic Baking       Groceries
# 39   ELEMOSM011            TechPro Smartphones Smart S     Electronics
# 698  GROBEJU002                 GoodEats Premium Juice       Groceries
# 354  SPOFIEQ007               FitZone Active Equipment          Sports
# 291  HOMCOPO004  HomeMaker Professional Pots & Pans XL  Home & Kitchen
# 407  SPOOUCA004             OutdoorEdge Active Camping          Sports
# 344  HOMFUDI006           HomeStyle Premium Dining Set  Home & Kitchen
# 213  CLOWOOU019               StyleX Relaxed Outerwear        Clothing
# 81   ELEAUSP006               Electra Speakers Ultra S     Electronics
# 432  BOOFIRO001                  ReadNow Guide Romance           Books
# ...

# %%
df_stores_clusters = pd.read_csv('../Data/eci_stores_clusters.csv')
df_stores_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STORE_ID    157 non-null    object
#  1   BRAND       157 non-null    object
#  2   STORE_NAME  157 non-null    object
#  3   CLUSTER     140 non-null    object
# dtypes: object(4)
# memory usage: 5.0+ KB

# %%
df_stores_clusters.sample(25)
# Out:
#       STORE_ID           BRAND                        STORE_NAME  \
# 102     S00103  EssentialsPlus         EssentialsPlus - Columbus
# 20      S00021   AsterionHouse              AsterionHouse - Mesa
# 63      S00064      LuxeRetail              LuxeRetail - Houston
# 101     S00102   MarketExpress         MarketExpress - Elizabeth
# 153     S00154      BudgetShop               BudgetShop - Newark
# 76      S00077        MegaShop                   MegaShop - Erie
# 67      S00068   MarketExpress          MarketExpress - Lakewood
# 18      S00019        QuickBuy              QuickBuy - Rochester
# 116     S00117        QuickBuy      QuickBuy Greensboro Westside
# 3    STORE0004        MegaShop          MegaShop - Oklahoma City
# 109     S00110  EssentialsPlus   EssentialsPlus Detroit Downtown
# 100     S00101      BudgetShop               BudgetShop - Albany
# 72      000073   AsterionHouse           AsterionHouse - Atlanta
# ...

# %%
df_stores = pd.read_csv('../Data/eci_stores.csv')
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STORE_ID    157 non-null    object
#  1   BRAND       157 non-null    object
#  2   STORE_NAME  157 non-null    object
#  3   ADDRESS1    157 non-null    object
#  4   ADDRESS2    43 non-null     object
#  5   CITY        157 non-null    object
#  6   STATE       157 non-null    object
#  7   ZIP         151 non-null    object
#  8   OPENDATE    157 non-null    object
#  9   CLOSEDATE   18 non-null     object
#  10  STORE_TYPE  155 non-null    object
#  11  REGION      157 non-null    object
# dtypes: object(12)
# memory usage: 14.8+ KB

# %%
df_stores.head(25)
# Out:
#      STORE_ID           BRAND                         STORE_NAME  \
# 0      S00001      PrimeGoods             PrimeGoods - Hillsboro
# 1      S00002        MegaShop     MegaShop Indianapolis Eastside
# 2   STORE0003   MarketExpress          MarketExpress - Las Vegas
# 3   STORE0004        MegaShop           MegaShop - Oklahoma City
# 4      S00005      PrimeGoods             PrimeGoods - Charlotte
# 5      000006   AsterionHouse              AsterionHouse - Miami
# 6      S00007      LuxeRetail                 LuxeRetail - Miami
# 7      000008      LuxeRetail          LuxeRetail Macon Downtown
# 8      S00009        MegaShop            MegaShop Detroit Center
# 9      S00010   AsterionHouse             AsterionHouse - Warren
# 10     S00011     FamilyStore  FamilyStore Indianapolis Eastside
# 11     S00012      PrimeGoods              PrimeGoods - Savannah
# 12     S00013   MarketExpress            MarketExpress - El Paso
# ...

# %% [markdown]
# ## Transacciones

# %%
df_transactions = pd.read_csv('../Data/eci_transactions.csv')
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19004759 entries, 0 to 19004758
# Data columns (total 9 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   TRANSACTION_ID          int64
#  1   DATE                    object
#  2   STORE_ID                object
#  3   SKU                     object
#  4   QUANTITY                float64
#  5   PRICE                   float64
#  6   TOTAL_SALES             float64
#  7   SUBGROUP                object
#  8   STORE_SUBGROUP_DATE_ID  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.3+ GB

# %%
df_transactions.sample(25)
# Out:
#           TRANSACTION_ID        DATE   STORE_ID         SKU  QUANTITY   PRICE  \
# 365014            370391  2021-01-21     000079  BOOEDTE010       1.0   23.29
# 13050710        13049518  2022-12-28     S00108  BEAMAFA010       NaN   48.86
# 5207070          5204116  2021-10-16     000052  HOMFULI003       1.0   56.89
# 11496738        11497123  2022-10-08     S00062  SPOOUCA001       1.0   73.66
# 4703464          4712850  2021-09-21     S00155  ELEMOSM008       1.0  269.41
# 18024604        18034244  2023-11-06     S00128  BEAHATR005       1.0   38.44
# 17565406        17570194  2023-10-11     S00085  HOMAPMA009       1.0   86.76
# 4245                1145  2021-01-01     S00009  GROPABA018       3.0    9.61
# 4831207          4815120  2021-09-27     000006  TOYEDLE003       1.0   27.54
# 4649863          4644787  2021-09-18     000094  CLOWODR011       1.0   46.54
# 1392111          1384854  2021-03-22     S00011  HOMFULI001       3.0   66.98
# ...

# %%
duplicados = df_transactions['TRANSACTION_ID'].duplicated()
df_transactions[duplicados]
# Out:
# Empty DataFrame
# Columns: [TRANSACTION_ID, DATE, STORE_ID, SKU, QUANTITY, PRICE, TOTAL_SALES, SUBGROUP, STORE_SUBGROUP_DATE_ID]
# Index: []

# %% [markdown]
# No se observan id duplicados en transactions.
#
# ### Análisis
#
# Para conocer las ganancias añadiremos los valores de base_price, initial_ticket_price y costos. Según los datos de product_master

# %%
df_transactions= pd.merge(df_transactions, df_product_master, left_on='SKU', right_on='sku', how='left')
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19159425 entries, 0 to 19159424
# Data columns (total 18 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   TRANSACTION_ID          int64
#  1   DATE                    object
#  2   STORE_ID                object
#  3   SKU                     object
#  4   QUANTITY                float64
#  5   PRICE                   float64
#  6   TOTAL_SALES             float64
#  7   SUBGROUP                object
#  8   STORE_SUBGROUP_DATE_ID  object
#  9   sku                     object
#  10  product_name            object
#  11  category                object
#  12  group                   object
#  13  subgroup                object
#  14  brand                   object
#  15  base_price              float64
#  16  initial_ticket_price    float64
#  17  costos                  float64
# dtypes: float64(6), int64(1), object(11)
# memory usage: 2.6+ GB

# %%
df_transactions.sample(25)
# Out:
#           TRANSACTION_ID        DATE   STORE_ID         SKU  QUANTITY   PRICE  \
# 16465443        16320419  2023-08-01     S00038  BEAMALI002       1.0   31.73
# 2410743          2388643  2021-05-22     S00088  SPOFISU001       1.0  100.75
# 17908571        17758132  2023-10-22     S00013  GROSNCH008       2.0    9.68
# 18776244        18617344  2023-12-08     S00013  TOYACFI002       3.0   31.34
# 14609010        14488129  2023-04-02     S00019  BOONOHI009       1.0   21.88
# 3155               15454  2021-01-01  STORE0133  TOYACVE004       3.0   30.34
# 10477208        10386861  2022-08-10     S00065  SPOTEBA001       1.0   80.41
# 12559996        12460165  2022-11-27     S00040  BOOEDRE002       1.0   24.19
# 17040287        16905058  2023-09-03     S00085  SPOOUCA002       3.0   77.17
# 16920301        16788280  2023-08-27  STORE0149  ELEAUHO003       1.0  280.80
# 6459048          6404259  2021-12-14     S00080  CLOCHIN009       1.0   42.11
# ...

# %%
df_test = pd.read_csv('../Data/ids_test.csv')
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77700 entries, 0 to 77699
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STORE_SUBGROUP_DATE_ID  77700 non-null  object
# dtypes: object(1)
# memory usage: 607.2+ KB

# %%
df_test.sample(25)
# Out:
#                    STORE_SUBGROUP_DATE_ID
# 44461            S00089_Coffee_2024-01-05
# 47499           S00095_Styling_2024-01-05
# 25830            000053_Baking_2024-01-01
# 59948              S00122_Eyes_2024-01-01
# 70191      S00143_Water Sports_2024-01-03
# 27603  S00057_Major Appliances_2024-01-03
# 64154             S00131_Pasta_2024-01-07
# 20867  S00043_Major Appliances_2024-01-01
# 64200          S00131_Vehicles_2024-01-04
# 41838             S00084_Chips_2024-01-07
# 48968           S00099_Romance_2024-01-04
# 72806   S00148_Science Fiction_2024-01-07
# 19200         S00040_Wearables_2024-01-07
# 26481            S00055_Shirts_2024-01-01
# 45878      STORE0092_Self-Help_2024-01-01
# 39730           S00080_Styling_2024-01-06
# 15227         S00032_Equipment_2024-01-03
# 39323     000079_Arts & Crafts_2024-01-05
# 58147          STORE0118_Girls_2024-01-06
# 21217       S00043_Board Games_2024-01-01
# 51917         S00106_Outerwear_2024-01-06
# ...
